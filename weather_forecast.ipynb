# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

data = pd.read_csv("DailyDelhiClimateTrain.csv")
print(data.head())
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
print(data.describe())
print(data.info())
# Out:
#           meantemp     humidity   wind_speed  meanpressure
# count  1462.000000  1462.000000  1462.000000   1462.000000
# mean     25.495521    60.771702     6.802209   1011.104548
# std       7.348103    16.769652     4.561602    180.231668
# min       6.000000    13.428571     0.000000     -3.041667
# 25%      18.857143    50.375000     3.475000   1001.580357
# 50%      27.714286    62.625000     6.221667   1008.563492
# 75%      31.305804    72.218750     9.238235   1014.944901
# max      38.714286   100.000000    42.220000   7679.333333
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   object
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 57.2+ KB
# None

# %%
figure = px.line(data, x="date", 
                 y="meantemp", 
                 title='Mean Temperature in Delhi Over the Years')
figure.show()

# %%
figure = px.line(data, x="date", 
                 y="humidity", 
                 title='Humidity in Delhi Over the Years')
figure.show()

# %%
figure = px.line(data, x="date", 
                 y="wind_speed", 
                 title='Wind Speed in Delhi Over the Years')
figure.show()

# %%
figure = px.scatter(data_frame = data, x="humidity",
                    y="meantemp", size="meantemp", 
                    trendline="ols", 
                    title = "Relationship Between Temperature and Humidity")
figure.show()

# %% [markdown]
# ## Analyzing Temperature Change
# Now let’s analyze the temperature change in Delhi over the years. For this task, I will first convert the data type of the date column into datetime. Then I will add two new columns in the dataset for year and month values.

# %%
data["date"] = pd.to_datetime(data["date"], format = '%Y-%m-%d')
data['year'] = data['date'].dt.year
data["month"] = data["date"].dt.month
print(data.head())
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure  year  month
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667  2013      1
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000  2013      1
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667  2013      1
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667  2013      1
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000  2013      1

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(15, 10))
plt.title("Temperature Change in Delhi Over the Years")
sns.lineplot(data = data, x='month', y='meantemp', hue='year')
plt.show()

# %% [markdown]
# ## Forecasting Weather using Python
#  The Facebook prophet model is one of the best techniques for time series forecasting. So for weather forecasting, we will be using Prophet model.

# %%
pip install prophet
# Out:
# Collecting prophet
#   Downloading prophet-1.1.5-py3-none-win_amd64.whl (13.3 MB)
#      ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#      --------------------------------------- 0.0/13.3 MB 660.6 kB/s eta 0:00:21
#      --------------------------------------- 0.0/13.3 MB 660.6 kB/s eta 0:00:21
#      --------------------------------------- 0.0/13.3 MB 660.6 kB/s eta 0:00:21
#      --------------------------------------- 0.1/13.3 MB 328.2 kB/s eta 0:00:41
#      --------------------------------------- 0.1/13.3 MB 547.6 kB/s eta 0:00:25
#      --------------------------------------- 0.1/13.3 MB 450.6 kB/s eta 0:00:30
#       -------------------------------------- 0.2/13.3 MB 620.6 kB/s eta 0:00:22
#       -------------------------------------- 0.2/13.3 MB 718.0 kB/s eta 0:00:19
 6.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15.4 in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from prophet) (1.24.4)
# Collecting cmdstanpy>=1.0.4
#   Downloading cmdstanpy-1.2.0-py3-none-any.whl (93 kB)
#      ---------------------------------------- 0.0/93.0 kB ? eta -:--:--
#      ---------------------------------------- 93.0/93.0 kB ? eta 0:00:00
# Requirement already satisfied: pandas>=1.0.4 in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from prophet) (2.0.3)
# Requirement already satisfied: importlib-resources in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from prophet) (6.1.1)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from prophet) (3.7.4)
# Collecting holidays>=0.25
#   Downloading holidays-0.40-py3-none-any.whl (889 kB)
#      ---------------------------------------- 0.0/889.6 kB ? eta -:--:--
#      ----------------- -------------------- 419.8/889.6 kB 8.7 MB/s eta 0:00:01
#      ------------------------------------  880.6/889.6 kB 11.2 MB/s eta 0:00:01
#      -------------------------------------- 889.6/889.6 kB 9.4 MB/s eta 0:00:00
# Collecting tqdm>=4.36.1
#   Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#      ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#      ---------------------------------------- 78.3/78.3 kB ? eta 0:00:00
# Collecting stanio~=0.3.0
#   Downloading stanio-0.3.0-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: python-dateutil in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from matplotlib>=2.0.0->prophet) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from matplotlib>=2.0.0->prophet) (10.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from importlib-resources->prophet) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from pandas>=1.0.4->prophet) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from pandas>=1.0.4->prophet) (2023.4)
# Requirement already satisfied: colorama in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\samay jain\anaconda3\envs\py3.8.11\lib\site-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)
# Installing collected packages: tqdm, stanio, holidays, cmdstanpy, prophet
# Successfully installed cmdstanpy-1.2.0 holidays-0.40 prophet-1.1.5 stanio-0.3.0 tqdm-4.66.1
# Note: you may need to restart the kernel to use updated packages.

# %%
forecast_data = data.rename(columns = {"date": "ds", 
                                       "meantemp": "y"})
print(forecast_data)
# Out:
#              ds          y    humidity  wind_speed  meanpressure  year  month
# 0    2013-01-01  10.000000   84.500000    0.000000   1015.666667  2013      1
# 1    2013-01-02   7.400000   92.000000    2.980000   1017.800000  2013      1
# 2    2013-01-03   7.166667   87.000000    4.633333   1018.666667  2013      1
# 3    2013-01-04   8.666667   71.333333    1.233333   1017.166667  2013      1
# 4    2013-01-05   6.000000   86.833333    3.700000   1016.500000  2013      1
# ...         ...        ...         ...         ...           ...   ...    ...
# 1457 2016-12-28  17.217391   68.043478    3.547826   1015.565217  2016     12
# 1458 2016-12-29  15.238095   87.857143    6.000000   1016.904762  2016     12
# 1459 2016-12-30  14.095238   89.666667    6.266667   1017.904762  2016     12
# 1460 2016-12-31  15.052632   87.000000    7.325000   1016.100000  2016     12
# 1461 2017-01-01  10.000000  100.000000    0.000000   1016.000000  2017      1
#
# [1462 rows x 7 columns]

# %%
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
model = Prophet()
model.fit(forecast_data)
forecasts = model.make_future_dataframe(periods=365*3) #365 = 1 year
predictions = model.predict(forecasts)
plot_plotly(model, predictions)
# Out:
# 19:17:41 - cmdstanpy - INFO - Chain [1] start processing
# 19:17:41 - cmdstanpy - INFO - Chain [1] done processing
